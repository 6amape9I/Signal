# %% [markdown]
# # Duplicates and Near-Duplicates
#
# This notebook inspects duplicate URLs, exact duplicates, and fuzzy duplicate candidates.

# %%
from analysis.src.load_dataset import load_raw_dataset
from analysis.src.normalize_columns import normalize_columns
from analysis.src.analyze_duplicates import analyze_duplicates

raw_df = load_raw_dataset()
normalized_df = normalize_columns(raw_df).dataframe
duplicates_result = analyze_duplicates(normalized_df)
duplicates_result["duplicate_urls_df"].head(20)

# %%
duplicates_result["near_duplicates_df"].head(20)
