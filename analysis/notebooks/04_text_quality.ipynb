# %% [markdown]
# # Text Quality
#
# This notebook inspects text lengths, suspicious short texts, and boilerplate candidates.

# %%
from analysis.src.load_dataset import load_raw_dataset
from analysis.src.normalize_columns import normalize_columns
from analysis.src.analyze_text_quality import analyze_text_quality

raw_df = load_raw_dataset()
normalized_df = normalize_columns(raw_df).dataframe
text_result = analyze_text_quality(normalized_df)
text_result["empty_or_short_df"].head(20)

# %%
text_result["boilerplate_candidates_df"].head(20)
