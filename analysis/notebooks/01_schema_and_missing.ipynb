# %% [markdown]
# # Schema and Missing Values
#
# This notebook inspects the raw Excel schema and missing-value profile using `analysis/src/` code.

# %%
from analysis.src.load_dataset import load_raw_dataset
from analysis.src.normalize_columns import normalize_columns
from analysis.src.analyze_schema import analyze_schema

raw_df = load_raw_dataset()
normalized = normalize_columns(raw_df)
schema_result = analyze_schema(normalized.dataframe, normalized)
schema_result["missing_df"].head(20)

# %%
schema_result["report"]
