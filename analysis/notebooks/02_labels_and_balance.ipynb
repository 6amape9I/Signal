# %% [markdown]
# # Labels and Balance
#
# This notebook explores class balance, small classes, and merge candidates.

# %%
from analysis.src.load_dataset import load_raw_dataset
from analysis.src.normalize_columns import normalize_columns
from analysis.src.analyze_labels import analyze_labels

raw_df = load_raw_dataset()
normalized_df = normalize_columns(raw_df).dataframe
labels_result = analyze_labels(normalized_df)
labels_result["distribution_df"].head(20)

# %%
labels_result["merge_candidates_df"].head(20)
